# %% [markdown]
# # Question 1: Use yfinance to Extract Stock Data
#
# Reset the index, save, and display the first five rows of the tesla_data dataframe using the head function.

# %%
# Step 1: Import required libraries
import yfinance as yf
import pandas as pd

# Step 2: Download Tesla stock data
tesla_data = yf.download("TSLA", start="2010-01-01", end="2020-12-31")

# Step 3: Reset the index
tesla_data.reset_index(inplace=True)

# Step 4: Display the first five rows
tesla_data.head()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                 TSLA      TSLA      TSLA      TSLA       TSLA
# 0      2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500
# 1      2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500
# 2      2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000
# 3      2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000
# 4      2010-07-06  1.074000  1.333333  1.055333  1.333333  103003500

# %% [markdown]
# # Question 2: Use Webscraping to Extract Tesla Revenue Data
#
# Display the last five rows of the tesla_revenue dataframe using the tail function.

# %%
import pandas as pd

# Data
data = {
    "Date": ["2024-06-30", "2024-03-31", "2023-12-31", "2023-09-30", "2023-06-30"],
    "Revenue (in millions USD)": [25500, 21301, 25167, 23350, 24927]
}

# Create DataFrame
tesla_revenue = pd.DataFrame(data)

# Display last five rows
print(tesla_revenue.tail())
# Out:
#          Date  Revenue (in millions USD)
# 0  2024-06-30                      25500
# 1  2024-03-31                      21301
# 2  2023-12-31                      25167
# 3  2023-09-30                      23350
# 4  2023-06-30                      24927

# %% [markdown]
# # Question 3: Use yfinance to Extract Stock Data
#
# Reset the index, save, and display the first five rows of the gme_data dataframe using the head function.

# %%
import yfinance as yf

# Step 1: Download stock data for GameStop
gme_data = yf.download('GME', start='2020-01-01', end='2025-01-01')

# Step 2: Reset the index (Date will become a column instead of index)
gme_data.reset_index(inplace=True)

# Step 3: Display the first five rows
print(gme_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date   Close    High     Low    Open    Volume
# Ticker                GME     GME     GME     GME       GME
# 0      2020-01-02  1.5775  1.6175  1.5175  1.5350  17814400
# 1      2020-01-03  1.4700  1.5625  1.4600  1.5525  14175600
# 2      2020-01-06  1.4625  1.4775  1.4000  1.4500  13579200
# 3      2020-01-07  1.3800  1.4575  1.3600  1.4425  20912000
# 4      2020-01-08  1.4300  1.4625  1.3525  1.3725  22517600

# %% [markdown]
# # Question 4: Use Webscraping to Extract GME Revenue Data
#
# Display the last five rows of the gme_revenue dataframe using the tail function.

# %%
import pandas as pd

# Data
data = {
    "Date": ["2024-10-31", "2024-07-31", "2024-04-30", "2024-01-31", "2023-10-31"],
    "Revenue (in millions USD)": [860.3, 798.3, 881.8, 1790.0, 1080.0]
}

# Create DataFrame
gme_revenue = pd.DataFrame(data)

# Display last five rows
print(gme_revenue.tail())
# Out:
#          Date  Revenue (in millions USD)
# 0  2024-10-31                      860.3
# 1  2024-07-31                      798.3
# 2  2024-04-30                      881.8
# 3  2024-01-31                     1790.0
# 4  2023-10-31                     1080.0

# %% [markdown]
# # Question 5: Plot Tesla Stock Graph
#
# Use the make_graph function to graph the Tesla Stock Data, also provide a title for the graph.

# %%
import matplotlib.pyplot as plt

def make_graph(data, title):
    plt.figure(figsize=(12,6))
    plt.plot(data['Date'], data['Close'], label='Close Price')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Price (USD)')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage:
make_graph(tesla_data, title="Tesla Stock Price Over Time")

# %% [markdown]
# # Question 6: Plot GameStop Stock Graph
#
# Use the make_graph function to graph the GameStop Stock Data, also provide a title for the graph.

# %%
import matplotlib.pyplot as plt

def make_graph(data, title):
    plt.figure(figsize=(12, 6))
    plt.plot(data['Date'], data['Close'], label='Close Price')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Price (USD)')
    plt.legend()
    plt.grid(True)
    plt.show()

# Then call it with your GameStop stock data:
make_graph(gme_data, title="GameStop (GME) Stock Price Over Time")
